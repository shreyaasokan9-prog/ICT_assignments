# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyaasokan9-prog/ICT_assignments/blob/main/assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter price of item 1:"))
b = int(input("Enter quantity of item1:"))
r = int(input("Enter price of item2:"))
s = int(input("Enter qauntity of item2:"))
amt =a*b
tma = r*s
sum = amt+tma
print("Total bill amount:",sum)
# Out:
# Enter price of item 1:45
# Enter quantity of item1:3
# Enter price of item2:30
# Enter qauntity of item2:2
# Total bill amount: 195

# %%
celsius= int(input("Enter temperature in celsius:"))
fahrenheit= (c*9/5)+32
print("Temperature in fahrenheit:",fahrenheit)
# Out:
# Enter temperature in celsius:30
# Temperature in fahrenheit: 86.0

# %%
b = int(input("Enter basic salary:"))
HRA = 0.20
DA = 0.10
total_salary = b + HRA + DA
print("Net salary:", total_salary)
# Out:
# Enter basic salary:20000
# Net salary: 20000.3

# %%
p = int(input("Enter principal amount:"))
r = int(input("Enter rate of interest:"))
t = int(input("Enter time:"))
SI = p*r*t/100
print("Simple interest:", SI)
# Out:
# Enter principal amount:10000
# Enter rate of interest:5
# Enter time:2
# Simple interest: 1000.0

# %%
t = int(input("Enter time in seconds:"))
hours = t//3600
minutes = (t%3600)//60
seconds = t%60
print("Time in hours:", hours)
print("Time in minutes:", minutes)
print("Time in seconds:", seconds)
# Out:
# Enter time in seconds:130
# Time in hours: 0
# Time in minutes: 2
# Time in seconds: 10

# %%
weight = float(input("Enter weight in kg:"))
height = float(input("Enter height in meters:"))
BMI = weight/(height)**2
print("BMI:", BMI)
# Out:
# Enter weight in kg:60
# Enter height in meters:1.65
# BMI: 22.03856749311295

# %%
original = int(input("Enter original number:"))
discount = 0.10*original
d = original - discount
print("discount price:",d)
# Out:
# Enter original number:1200
# discount price: 1080.0

# %%
a = int(input("Enter side A OF TRIANGLE:"))
b = int(input("Enter side B OF TRIANGLE:"))
c = int(input("Enter side C OF TRIANGLE:"))
S = (a+b+c)/2
area = (S*(S-a)*(S-b)*(S-c))**0.5
print("Area of triangle:",area)
# Out:
# Enter side A OF TRIANGLE:5
# Enter side B OF TRIANGLE:6
# Enter side C OF TRIANGLE:7
# Area of triangle: 14.696938456699069

# %%
w = int(input("Enter wall length:"))
h = int(input("Enter wall height:"))
w = 1.5*1.2
p = w*h
pa = p-w
cost = pa*25
print('total area of be painted:',pa)
print("total cost for painting:",cost)
# Out:
# Enter wall length:12
# Enter wall height:8
# total area of be painted: 12.599999999999998
# total cost for painting: 314.99999999999994

# %%
a =int(input("Enter number of units consumed"))
unit = 250
bill =(unit*5.2)+100
print("Electricity bill:",bill)
# Out:
# Enter number of units consumed250
# Electricity bill: 1400.0
